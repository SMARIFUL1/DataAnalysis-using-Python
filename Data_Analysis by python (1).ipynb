# %% [markdown]
# # Data_Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# Data checking

# %%
df=pd.read_csv('movies.csv')

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
pd.isnull(df).sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %% [markdown]
# Alternative way to check null or missing values

# %%
for col in df.columns:
    print(df[col].isnull().value_counts(), "\n")
# Out:
# False    7668
# Name: name, dtype: int64
#
# False    7591
# True       77
# Name: rating, dtype: int64
#
# False    7668
# Name: genre, dtype: int64
#
# False    7668
# Name: year, dtype: int64
#
# False    7666
# True        2
# Name: released, dtype: int64
#
# False    7665
# True        3
# Name: score, dtype: int64
#
# False    7665
# True        3
# Name: votes, dtype: int64
#
# False    7668
# Name: director, dtype: int64
#
# False    7665
# True        3
# Name: writer, dtype: int64
#
# False    7667
# True        1
# Name: star, dtype: int64
#
# False    7665
# True        3
# Name: country, dtype: int64
#
# False    5497
# True     2171
# Name: budget, dtype: int64
#
# False    7479
# True      189
# Name: gross, dtype: int64
#
# False    7651
# True       17
# Name: company, dtype: int64
#
# False    7664
# True        4
# Name: runtime, dtype: int64

# %%
#If there any outliers
df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
#To save time just drop rows that have missing data
data = df.dropna()

# %%
#to change data into int. from float

data['budget']= data['budget'].astype('int64')
data['gross']= data['gross'].astype('int64')
# Out:
# C:\Users\ARIF\AppData\Local\Temp/ipykernel_12808/2411140670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['budget']= data['budget'].astype('int64')
# C:\Users\ARIF\AppData\Local\Temp/ipykernel_12808/2411140670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gross']= data['gross'].astype('int64')

# %%
data.tail(5)
# Out:
#                       name     rating      genre  year  \
# 7648     Bad Boys for Life          R     Action  2020
# 7649    Sonic the Hedgehog         PG     Action  2020
# 7650              Dolittle         PG  Adventure  2020
# 7651  The Call of the Wild         PG  Adventure  2020
# 7652     The Eight Hundred  Not Rated     Action  2020
#
#                                released  score     votes        director  \
# 7648   January 17, 2020 (United States)    6.6  140000.0    Adil El Arbi
# 7649  February 14, 2020 (United States)    6.5  102000.0     Jeff Fowler
# 7650   January 17, 2020 (United States)    5.6   53000.0  Stephen Gaghan
# 7651  February 21, 2020 (United States)    6.8   42000.0   Chris Sanders
# 7652    August 28, 2020 (United States)    6.8    3700.0         Hu Guan
#
#               writer               star        country     budget      gross  \
# 7648     Peter Craig         Will Smith  United States   90000000  426505244
# ...

# %% [markdown]
# #to extract year from released column

# %%
data['year_corrected'] = data['released'].str.extract(pat = '([0-9]{4})') # this is known as regex expression.So, here [0-9] means the number range and {4} means united 4 numbers at a time
data.head()
# Out:
# C:\Users\ARIF\AppData\Local\Temp/ipykernel_12808/3633037887.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year_corrected'] = data['released'].str.extract(pat = '([0-9]{4})') # this is known as regex expression.So, here [0-9] means the number range and {4} means united 4 numbers at a time
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# ...

# %%
#sorting values based on gross column in descending order
data.sort_values(by='gross',ascending=False,inplace=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
#To see maximum row use this command and then click on desired data
pd.set_option('display.max_rows', None)

# %%
#To drop duplicates if exists
data['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
#Comparing gross earning regarding budget
plt.figure(figsize=(14,8))
plt.scatter(x=data['budget'],y=data['gross'],marker='o')
plt.title('Gross earning vs Budget')
plt.xlabel('Budget')
plt.ylabel('Gross income')
# Out:
# Text(0, 0.5, 'Gross income')

# %%
plt.figure(figsize=(14,8))
sns.regplot(data=data,x='budget',y='gross',scatter_kws={'color':'black'},line_kws={'color':'blue'},marker='*')
plt.title('Gross earning vs Budget')
plt.xlabel('Budget')
plt.ylabel('Gross income')
# Out:
# Text(0, 0.5, 'Gross income')

# %%
#To see correlation between different data

# %%
df_corr=data.corr(method='pearson')
df_corr
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# #we can see above that there is high correlation between budget & gross

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=df_corr, annot=True)
plt.title('Correlation between different features')
# Out:
# Text(0.5, 1.0, 'Correlation between different features')

# %% [markdown]
# #Object columns convert into numeric column

# %%
numeric_data=data

for col_name in numeric_data.columns:
    if (numeric_data[col_name].dtype == 'object'):
        numeric_data[col_name] =numeric_data[col_name].astype('category')
        numeric_data[col_name] = numeric_data[col_name].cat.codes


numeric_data.head()
# Out:
# C:\Users\ARIF\AppData\Local\Temp/ipykernel_12808/3965366181.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_data[col_name] =numeric_data[col_name].astype('category')
# C:\Users\ARIF\AppData\Local\Temp/ipykernel_12808/3965366181.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_data[col_name] = numeric_data[col_name].cat.codes
#    name  rating  genre  year  released  score      votes  director  writer  \
# ...

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name      name        1.000000
#           rating      0.143938
#           genre       0.036367
#           year        0.965761
#           released    0.959015
#           score      -0.046733
#           votes       0.287776
#           director    0.745905
#           writer      0.805211
#           star        0.731565
#           country     0.142828
#           budget      0.277488
#           gross       0.947324
#           company     0.591667
#           runtime     0.048955
# rating    name        0.143938
#           rating      1.000000
#           genre      -0.086723
#           year        0.156713
#           released    0.146606
#           score       0.012595
#           votes       0.099972
#           director    0.085520
#           writer      0.103623
#           star        0.093116
#           country     0.000494
#           budget      0.193353
#           gross       0.158582
#           company    -0.028035
#           runtime     0.032741
# ...

# %%
# Looking at the top 15 compaies by gross revenue

Company_GrossSum = df.groupby('company')[["gross"]].sum()

Company_GrossSum_sorting = Company_GrossSum.sort_values('gross', ascending = False)[:15]

Company_GrossSum_sorting= Company_GrossSum_sorting['gross'].astype('int64') 

Company_GrossSum_sorting
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
sns.swarmplot(x="rating", y="gross", data=df)

# %%
sns.stripplot(x="rating", y="gross", data=df)

# %% [markdown]
# Thanks
